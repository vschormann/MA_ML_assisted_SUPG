# %%
from Training_utils import train_loader, train
import torch_geometric as tg
import torch
from SUPG_prediction_models import *

batch_size = 15
train_loader = train_loader(batch_size=batch_size)


    
model = SigmoidRestriction(GAT)


optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, factor=0.9, patience=50)
curr_loss = 5

# %%
for i in range(2000):
    loss = train(model=model, loader=train_loader, optimizer=optimizer, device='cpu')
    if loss > curr_loss:
        print(f"iteration: {i}, loss: {loss}, model loss: {curr_loss}:")
    elif loss <= curr_loss:
        print(f"iteration: {i}, new model loss: {loss}")
    torch.save({'model_state': model.state_dict(), 'optimizer_state': optimizer.state_dict(), 'loss': loss}, "data/models/sigmoid_GAT_supervised.pth")
    scheduler.step(loss)
# Out:
# iteration: 0, new model loss: 0.7668341298898061
# iteration: 1, new model loss: 0.7660988370577494
# iteration: 2, new model loss: 0.7653787732124329
# iteration: 3, new model loss: 0.7646676301956177
# iteration: 4, new model loss: 0.763962060213089
# iteration: 5, new model loss: 0.7632600665092468
# iteration: 6, new model loss: 0.7625609338283539
# iteration: 7, new model loss: 0.7618639369805654
# iteration: 8, new model loss: 0.7611689368883768
# iteration: 9, new model loss: 0.760475754737854
# iteration: 10, new model loss: 0.7597843110561371
# iteration: 11, new model loss: 0.7590945760409037
# iteration: 12, new model loss: 0.7584065000216166
# iteration: 13, new model loss: 0.7577200631300608
# iteration: 14, new model loss: 0.7570351759592692
# iteration: 15, new model loss: 0.7563520669937134
# iteration: 16, new model loss: 0.7556704878807068
# iteration: 17, new model loss: 0.7549905677636465
# iteration: 18, new model loss: 0.7543122669061025
# iteration: 19, new model loss: 0.7536355455716451
# iteration: 20, new model loss: 0.7529605130354563
# iteration: 21, new model loss: 0.7522870004177094
# iteration: 22, new model loss: 0.7516151368618011
# iteration: 23, new model loss: 0.7509448925654093
# iteration: 24, new model loss: 0.7502761880556742
# iteration: 25, new model loss: 0.7496092220147451
# iteration: 26, new model loss: 0.7489437460899353
# iteration: 27, new model loss: 0.748279869556427
# iteration: 28, new model loss: 0.74761763215065
# iteration: 29, new model loss: 0.7469569047292074
# iteration: 30, new model loss: 0.7462978561719259
# iteration: 31, new model loss: 0.7456402679284414
# iteration: 32, new model loss: 0.7449843486150106
# iteration: 33, new model loss: 0.744329959154129
# iteration: 34, new model loss: 0.7436772088209788
# iteration: 35, new model loss: 0.7430259684721628
# iteration: 36, new model loss: 0.742376297712326
# iteration: 37, new model loss: 0.7417282164096832
# iteration: 38, new model loss: 0.7410816848278046
# iteration: 39, new model loss: 0.740436722834905
# iteration: 40, new model loss: 0.7397933502991995
# iteration: 41, new model loss: 0.7391514778137207
# iteration: 42, new model loss: 0.7385111351807913
# iteration: 43, new model loss: 0.7378723522027334
# iteration: 44, new model loss: 0.7372351785500845
# iteration: 45, new model loss: 0.73659947514534
# iteration: 46, new model loss: 0.7359653015931448
# iteration: 47, new model loss: 0.735332727432251
# iteration: 48, new model loss: 0.7347016334533691
# iteration: 49, new model loss: 0.7340721090634664
# iteration: 50, new model loss: 0.7334440350532532
# iteration: 51, new model loss: 0.732817530632019
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/MA_ML_assisted_SUPG/SUPG_prediction_models.py:251, in SigmoidRestriction.forward(self, data)
#     249 def forward(self, data) -> torch.Tensor:
#     250     upper = data.upper
# --> 251     model_out = self.model(data)
#     252     return upper*model_out.sigmoid()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/MA_ML_assisted_SUPG/SUPG_prediction_models.py:156, in GAT.forward(self, data)
#     154 h = self.conv5(x=h, edge_index=edge_index)
#     155 h = h.relu()
# --> 156 h = self.conv6(x=h, edge_index=edge_index)
#     157 h = h.relu()
#     158 h = self.conv7(x=h, edge_index=edge_index)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch_geometric/nn/conv/gat_conv.py:362, in GATConv.forward(self, x, edge_index, edge_attr, size, return_attention_weights)
#     356             raise NotImplementedError(
#     357                 "The usage of 'edge_attr' and 'add_self_loops' "
#     358                 "simultaneously is currently not yet supported for "
#     359                 "'edge_index' in a 'SparseTensor' form")
#     361 # edge_updater_type: (alpha: OptPairTensor, edge_attr: OptTensor)
# --> 362 alpha = self.edge_updater(edge_index, alpha=alpha, edge_attr=edge_attr,
#     363                           size=size)
#     365 # propagate_type: (x: OptPairTensor, alpha: Tensor)
#     366 out = self.propagate(edge_index, x=x, alpha=alpha, size=size)
#
# File /var/folders/hy/wm6pk5yx2292rjh5y0x_t8k80000gn/T/torch_geometric.nn.conv.gat_conv_GATConv_edge_updater_j97i4rk2.py:145, in edge_updater(self, edge_index, alpha, edge_attr, size)
#     135 def edge_updater(
#     136     self,
#     137     edge_index: Union[Tensor, SparseTensor],
#    (...)
#     140     size: Size = None,
#     141 ) -> Tensor:
#     143     mutable_size = self._check_input(edge_index, size)
# --> 145     kwargs = self.edge_collect(
#     146         edge_index,
#     147         alpha,
#     148         edge_attr,
#     149         mutable_size,
#     150     )
#     152     # Begin Edge Update Forward Pre Hook #######################################
#     153     if not torch.jit.is_scripting() and not is_compiling():
#
# File /var/folders/hy/wm6pk5yx2292rjh5y0x_t8k80000gn/T/torch_geometric.nn.conv.gat_conv_GATConv_edge_updater_j97i4rk2.py:109, in edge_collect(self, edge_index, alpha, edge_attr, size)
#     107 if isinstance(_alpha_1, Tensor):
#     108     self._set_size(size, 1, _alpha_1)
# --> 109     alpha_i = self._index_select(_alpha_1, edge_index_i)
#     110 else:
#     111     alpha_i = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch_geometric/nn/conv/message_passing.py:267, in MessagePassing._index_select(self, src, index)
#     265     return src.index_select(self.node_dim, index)
#     266 else:
# --> 267     return self._index_select_safe(src, index)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch_geometric/nn/conv/message_passing.py:271, in MessagePassing._index_select_safe(self, src, index)
#     269 def _index_select_safe(self, src: Tensor, index: Tensor) -> Tensor:
#     270     try:
# --> 271         return src.index_select(self.node_dim, index)
#     272     except (IndexError, RuntimeError) as e:
#     273         if index.numel() > 0 and index.min() < 0:
#
# KeyboardInterrupt:
