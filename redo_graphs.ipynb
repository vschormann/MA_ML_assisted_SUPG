# %%
import torch

for idx in range(88):
    G = torch.load(f'data/training_set/input_values/raw/G_{idx}.pt', weights_only=False)
    print(idx, G.x[:,9][0].item(), G.prblm_id)
# Out:
# 0 4.0 0
# 1 4.0 0
# 2 4.0 0
# 3 4.0 0
# 4 4.0 0
# 5 4.0 0
# 6 4.0 0
# 7 4.0 0
# 8 4.0 0
# 9 4.0 0
# 10 4.0 0
# 11 4.0 0
# 12 4.0 0
# 13 4.0 0
# 14 4.0 1
# 15 4.0 1
# 16 4.0 1
# 17 4.0 1
# 18 4.0 1
# 19 4.0 1
# 20 4.0 1
# 21 4.0 1
# 22 4.0 1
# 23 4.0 2
# 24 4.0 2
# 25 4.0 2
# 26 4.0 2
# 27 4.0 2
# 28 4.0 2
# 29 4.0 2
# 30 4.0 2
# 31 4.0 2
# 32 4.0 2
# 33 4.0 2
# 34 4.0 2
# 35 4.0 2
# 36 4.0 2
# 37 4.0 2
# 38 4.0 2
# 39 4.0 3
# 40 4.0 3
# 41 4.0 3
# 42 4.0 3
# 43 4.0 3
# 44 4.0 3
# 45 4.0 3
# 46 4.0 3
# 47 4.0 3
# 48 4.0 3
# 49 4.0 3
# 50 4.0 3
# 51 4.0 3
# 52 4.0 3
# 53 4.0 3
# 54 4.0 0
# 55 2.0 0
# 56 2.0 0
# 57 2.0 0
# 58 2.0 1
# 59 2.0 1
# 60 2.0 1
# 61 2.0 1
# 62 2.0 2
# 63 2.0 2
# 64 2.0 2
# 65 2.0 2
# 66 2.0 3
# 67 2.0 3
# 68 2.0 3
# 69 3.0 3
# 70 4.0 4
# 71 4.0 4
# 72 4.0 4
# 73 4.0 5
# 74 4.0 5
# 75 4.0 5
# 76 4.0 5
# 77 4.0 6
# 78 4.0 6
# 79 4.0 6
# 80 4.0 6
# 81 2.0 4
# 82 2.0 4
# 83 2.0 4
# 84 2.0 5
# 85 2.0 5
# 86 2.0 5
# 87 2.0 5
