# %% [markdown]
# # Chapter 5 revised-model analysis
#
# **Status:** canonical thesis analysis
# **Thesis sections:** 5.1.2 and 5.2
# **Inputs:** revised dataset and checkpoints
# **Reproduces:** Figures 38-42
#
# Keep target perturbation, local-predictor lower bounds, MLP/GATv2 loss histories, FEM metrics, and boundary/crosswind line plots together because they support one conclusion about non-unique targets and long-range dependencies.

# %%
import json
from supgml.experiments import project_root

run_directory = project_root() / "runs/ch5_revised"
# summary = json.loads((run_directory / "summary.json").read_text())

# %% [markdown]
# ## Expected interpretation
#
# The revised GATv2 fits the targets and AFC-BJK reference more closely than the revised MLP, but neither reaches the theoretical local-predictor bound and both retain outflow artifacts.
