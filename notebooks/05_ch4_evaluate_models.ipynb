# %% [markdown]
# # Chapter 4 model evaluation
#
# **Status:** canonical thesis analysis
# **Thesis sections:** 4.1-4.8
# **Inputs:** Chapter 4 checkpoints and the 14-case test set
# **Outputs:** architecture comparison tables and SPDE plots
#
# This notebook should reproduce only the MLP/GCN/SAGE/GAT/GATv2 comparison. Alternative graph structures and dense attention experiments are kept in the archive.

# %%
from supgml.evaluation import evaluate_models
from supgml.viz import FieldGrid

# Load models from checkpoint metadata, then evaluate_models(solver, graph, models).

# %% [markdown]
# ## Reporting rule
#
# Report both numerical metrics and the thesis's qualitative usability judgement. The loss values alone did not reliably identify oscillations or layer smearing.
