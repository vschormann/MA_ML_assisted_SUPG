# %% [markdown]
# # Render thesis figures
#
# **Status:** canonical reporting notebook
# **Inputs:** immutable datasets, checkpoints, and run summaries
# **Outputs:** `gallery` and publication figures
#
# This notebook performs no training and does not modify stored graphs. It exists solely to regenerate tables, field plots, and line plots from named artifacts.

# %%
from supgml.experiments import project_root
from supgml.viz import FieldGrid

gallery = project_root() / "gallery"

# %% [markdown]
# Every figure cell should name the corresponding thesis figure and save to a deterministic filename. Experimental plots that do not appear in the thesis belong in the archive notebook that motivated them.
