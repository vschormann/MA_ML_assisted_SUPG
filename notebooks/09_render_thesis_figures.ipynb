# %% [markdown]
# # Thesis figure reporting template
#
# **Role:** maintained post-submission guide
# **Execution scope:** template; its figure specification is intentionally unpopulated and required artefacts are ignored
#
# This notebook records how a future read-only reporting stage should map figures to graph cases, checkpoints, and run summaries. It does not regenerate the thesis figures from a fresh clone; the historical exports are under `docs/assets/thesis-figures/`.

# %% [markdown]
# ## Figure provenance
#
# Every figure should identify its thesis number, source case/checkpoint, reference solution, plotted quantity, and deterministic output filename. Keeping this mapping next to the rendering code makes a figure auditable without reopening experimental notebooks.

# %%
from supgml.experiments import project_root

root = project_root()
gallery = root / "gallery"
figure_specification = {
    # "figure_38": {"case": "revised_spde3", "checkpoint": "revised-gatv2.pth"},
}
gallery.mkdir(exist_ok=True)

# %% [markdown]
# ## Render comparable fields and line cuts
#
# Use one colormap range per comparison, label the reference and model explicitly, and save vector/raster outputs under a stable filename. `supgml.viz` packages the repeated mesh-to-plot conversion; choose the quantities and comparisons here.

# %%
from supgml.viz import FieldGrid

# grid = FieldGrid(...)
# grid.add_field(reference, title="AFC-BJK reference")
# grid.add_field(prediction, title="revised GATv2")
# grid.save(gallery / "figure_38_revised_comparison.png")

# %% [markdown]
# Exploratory plots that were not used in the thesis remain with the archived notebook that generated them. This protects the final gallery from silently mixing abandoned ideas with reported evidence.
